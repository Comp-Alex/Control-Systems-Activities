# %%
import control as ctrl
import matplotlib.pyplot as plt

# %%
# Basta pang Define daw transfer function
# G(s) = 10(s+2) / [s(s+5)(s+10)]
num = [10, 20]  # Eto sa Numerator: 10s + 20
den = [1, 15, 50, 0]  # Eto sa Denominator: s^3 + 15s^2 + 50s

G = ctrl.tf(num, den)
print(G)
# Out:
# <TransferFunction>: sys[0]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#        10 s + 20
#   -------------------
#   s^3 + 15 s^2 + 50 s

# %%
# Basta pang Calculate at plot response
t, y = ctrl.step_response(G)
plt.title("Time Response of G(s)")
plt.plot(t, y)
plt.xlabel("Time (s)")
plt.ylabel("Output")
plt.grid()
plt.show()
PythonFinalizationError: plt
